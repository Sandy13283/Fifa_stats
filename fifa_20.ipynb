# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandy13283/Fifa_stats/blob/main/fifa_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa=pd.read_csv('/content/drive/MyDrive/Data_set/fifa/players_20.csv')
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
for col in fifa.columns:
  print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
fifa['nationality'].value_counts()[0:20]
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
# Brazil                  824
# Italy                   732
# Colombia                591
# Japan                   453
# Netherlands             416
# China PR                373
# Chile                   370
# Sweden                  358
# Norway                  350
# Republic of Ireland     348
# United States           347
# Denmark                 345
# Portugal                344
# Mexico                  340
# Poland                  324
# Name: nationality, dtype: int64

# %%
plt.bar(list(fifa['nationality'].value_counts().keys()[0:8]),list(fifa['nationality'].value_counts()[0:8]),color='purple')
plt.show()

# %%
player_salary=fifa[['short_name','wage_eur']]
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
player_salary=player_salary.sort_values(by='wage_eur',ascending=False)
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 22       A. Griezmann    370000
# 5        K. De Bruyne    370000

# %%
plt.bar(list(player_salary['short_name'])[0:10],list(player_salary['wage_eur'])[0:10],color=["purple","hotpink","blue",'red','yellow','green','olive','darkolivegreen','midnightblue'])
plt.show()

# %%
Germany=fifa[fifa['nationality']=='Germany']
Germany.head(10)
# Out:
#      sofifa_id                                         player_url  \
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 61      212622  https://sofifa.com/player/212622/joshua-kimmic...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
# 77      212190  https://sofifa.com/player/212190/niklas-sule/2...
# 109     235790  https://sofifa.com/player/235790/kai-havertz/2...
#
#         short_name              long_name  age         dob  height_cm  \
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31        M. Neuer           Manuel Neuer   33  1986-03-27        193
# ...

# %%
India=fifa[fifa['nationality']=='India']
India.head()
# Out:
#        sofifa_id                                         player_url  \
# 12155     251742  https://sofifa.com/player/251742/gajodara-chat...
# 13102     251723  https://sofifa.com/player/251723/prakul-bhatt/...
# 13103     251728  https://sofifa.com/player/251728/bhadrashree-r...
# 13970     251722  https://sofifa.com/player/251722/abhimoda-chak...
# 13971     251727  https://sofifa.com/player/251727/hantidev-bhan...
#
#            short_name             long_name  age         dob  height_cm  \
# 12155   G. Chatterjee   Gajodara Chatterjee   33  1985-07-04        195
# 13102        P. Bhatt          Prakul Bhatt   34  1985-04-07        182
# 13103          B. Raj       Bhadrashree Raj   31  1988-03-25        175
# 13970  A. Chakraborty  Abhimoda Chakraborty   33  1985-10-27        189
# 13971     H. Bhandari     Hantidev Bhandari   30  1989-06-22        178
#
#        weight_kg nationality   club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %%
India.sort_values(by='height_cm',ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 12155     251742  https://sofifa.com/player/251742/gajodara-chat...
# 13970     251722  https://sofifa.com/player/251722/abhimoda-chak...
# 16303     251733  https://sofifa.com/player/251733/palkesh-nagar...
# 15205     251747  https://sofifa.com/player/251747/anuvinda-khur...
# 15866     251726  https://sofifa.com/player/251726/diasha-sundar...
#
#            short_name             long_name  age         dob  height_cm  \
# 12155   G. Chatterjee   Gajodara Chatterjee   33  1985-07-04        195
# 13970  A. Chakraborty  Abhimoda Chakraborty   33  1985-10-27        189
# 16303    P. Nagarajan     Palkesh Nagarajan   29  1989-10-12        189
# 15205      A. Khurana      Anuvinda Khurana   26  1993-04-21        186
# 15866     D. Sundaram       Diasha Sundaram   30  1989-04-28        186
#
#        weight_kg nationality   club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %%
India.sort_values(by='wage_eur',ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 12155     251742  https://sofifa.com/player/251742/gajodara-chat...
# 15324     251732  https://sofifa.com/player/251732/remil-nadkarn...
# 16354     251745  https://sofifa.com/player/251745/chapal-palan/...
# 16353     251735  https://sofifa.com/player/251735/amanpreet-var...
# 16352     251724  https://sofifa.com/player/251724/taranjot-agar...
#
#           short_name            long_name  age         dob  height_cm  \
# 12155  G. Chatterjee  Gajodara Chatterjee   33  1985-07-04        195
# 15324    R. Nadkarni       Remil Nadkarni   33  1985-10-31        180
# 16354       C. Palan         Chapal Palan   28  1991-06-20        181
# 16353      A. Varkay     Amanpreet Varkay   33  1985-08-18        179
# 16352     T. Agarwal     Taranjot Agarwal   33  1986-02-15        173
#
#        weight_kg nationality   club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %%
India[['short_name','age','wage_eur','sofifa_id']].sort_values(by='age',ascending=False).head()
# Out:
#          short_name  age  wage_eur  sofifa_id
# 15321  A. Deshpande   38         0     251721
# 15868      D. Bajwa   38         0     251748
# 15322      T. Atwal   35         0     251725
# 16714    D. Singhal   34         0     251750
# 15867  R. Jayaraman   34         0     251746

# %%
player_shooting=fifa[['short_name','shooting','nationality','wage_eur']]
player_shooting.sort_values(by=['wage_eur'],ascending=False).head(10)
# Out:
#            short_name  shooting nationality  wage_eur
# 0            L. Messi      92.0   Argentina    565000
# 4           E. Hazard      83.0     Belgium    470000
# 1   Cristiano Ronaldo      93.0    Portugal    405000
# 5        K. De Bruyne      86.0     Belgium    370000
# 22       A. Griezmann      86.0      France    370000
# 19          L. Suárez      89.0     Uruguay    355000
# 8           L. Modrić      76.0     Croatia    340000
# 36           T. Kroos      80.0     Germany    330000
# 17          S. Agüero      90.0   Argentina    300000
# 21    Sergio Busquets      62.0       Spain    300000
